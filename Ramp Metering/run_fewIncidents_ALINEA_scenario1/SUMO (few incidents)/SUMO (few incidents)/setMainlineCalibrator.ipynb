# %%
import xml
import xml.etree.ElementTree as ET

m_encoding = 'UTF-8'

# %% [markdown]
# # Segment 1

# %%
carTau_seg1 = "1.3"
carMinGap_seg1 = "3.0"
carSigma_seg1 = "0.2"
carSpeedFactor_seg1 = "normc(1.0,0.1,1.0,1.2)"
carCooperative_seg1 = "0.8"
carStrategic_seg1 = "10"
carSpeedGain_seg1 = "5"
carAssertive_seg1 = "2"

hovTau_seg1 = "1.3"
hovMinGap_seg1 = "3.0"
hovSigma_seg1 = "0.2"
hovSpeedFactor_seg1 = "normc(1.0,0.1,1.0,1.2)"
hovCooperative_seg1 = "0.8"
hovStrategic_seg1 = "10"
hovSpeedGain_seg1 = "5"
hovAssertive_seg1 = "2"

lightTruckTau_seg1 = "1.5"
lightTruckMinGap_seg1 = "3.5"
lightTruckSigma_seg1 = "0.2"
lightTruckSpeedFactor_seg1 = "normc(1.0,0.05,1.0,1.2)"
lightTruckCooperative_seg1 = "0.8"
lightTruckStrategic_seg1 = "10"
lightTruckSpeedGain_seg1 = "5"
lightTruckAssertive_seg1 = "1"

heavyTruckTau_seg1 = "1.5"
heavyTruckMinGap_seg1 = "3.5"
heavyTruckSigma_seg1 = "0.2"
heavyTruckSpeedFactor_seg1 = "normc(1.0,0.05,1.0,1.2)"
heavyTruckCooperative_seg1 = "0.8"
heavyTruckStrategic_seg1 = "10"
heavyTruckSpeedGain_seg1 = "5"
heavyTruckAssertive_seg1 = "1"

data = ET.Element('additional')

# car.
for i, vehLen in enumerate(["5.0", "5.5", "6.0"]):
    ET.SubElement(data, "vType", 
                  id="car{}_seg1".format(i+1), 
                  vClass="passenger",
                  length=vehLen,
                  tau=carTau_seg1,
                  minGap=carMinGap_seg1,
                  sigma=carSigma_seg1,
                  speedFactor=carSpeedFactor_seg1,
                  lcCooperative=carCooperative_seg1,
                  lcStrategic=carStrategic_seg1,
                  lcSpeedGain=carSpeedGain_seg1,
                  lcAssertive=carAssertive_seg1,
                  startupDelay="1")
    
    ET.SubElement(data, "vType", 
                  id="car{}_cv_seg1".format(i+1), 
                  vClass="passenger",
                  length=vehLen,
                  tau=carTau_seg1,
                  minGap=carMinGap_seg1,
                  sigma=carSigma_seg1,
                  speedFactor=carSpeedFactor_seg1,
                  lcCooperative=carCooperative_seg1,
                  lcStrategic=carStrategic_seg1,
                  lcSpeedGain=carSpeedGain_seg1,
                  lcAssertive=carAssertive_seg1,
                  startupDelay="1")

# HOV.
for i, vehLen in enumerate(["5.0", "5.5", "6.0"]):
    ET.SubElement(data, "vType", 
                  id="hov{}_seg1".format(i+1), 
                  vClass="hov",
                  length=vehLen,
                  tau=hovTau_seg1,
                  minGap=hovMinGap_seg1,
                  sigma=hovSigma_seg1,
                  speedFactor=hovSpeedFactor_seg1,
                  lcCooperative=hovCooperative_seg1,
                  lcStrategic=hovStrategic_seg1,
                  lcSpeedGain=hovSpeedGain_seg1,
                  lcAssertive=hovAssertive_seg1,
                  startupDelay="1")
    
    
    ET.SubElement(data, "vType", 
                  id="hov{}_cv_seg1".format(i+1), 
                  vClass="hov",
                  length=vehLen,
                  tau=hovTau_seg1,
                  minGap=hovMinGap_seg1,
                  sigma=hovSigma_seg1,
                  speedFactor=hovSpeedFactor_seg1,
                  lcCooperative=hovCooperative_seg1,
                  lcStrategic=hovStrategic_seg1,
                  lcSpeedGain=hovSpeedGain_seg1,
                  lcAssertive=hovAssertive_seg1,
                  startupDelay="1")


# Light trucks.
for i, vehLen in enumerate(["7.0", "7.5", "8.0"]):
    ET.SubElement(data, "vType", 
                  id="lightTruck{}_seg1".format(i+1), 
                  vClass="truck",
                  length=vehLen,
                  tau=lightTruckTau_seg1,
                  minGap=lightTruckMinGap_seg1,
                  sigma=lightTruckSigma_seg1,
                  speedFactor=lightTruckSpeedFactor_seg1,
                  lcCooperative=lightTruckCooperative_seg1,
                  lcStrategic=lightTruckStrategic_seg1,
                  lcSpeedGain=lightTruckSpeedGain_seg1,
                  lcAssertive=lightTruckAssertive_seg1,
                  startupDelay="1")
    
    
    ET.SubElement(data, "vType", 
                  id="lightTruck{}_cv_seg1".format(i+1), 
                  vClass="truck",
                  length=vehLen,
                  tau=lightTruckTau_seg1,
                  minGap=lightTruckMinGap_seg1,
                  sigma=lightTruckSigma_seg1,
                  speedFactor=lightTruckSpeedFactor_seg1,
                  lcCooperative=lightTruckCooperative_seg1,
                  lcStrategic=lightTruckStrategic_seg1,
                  lcSpeedGain=lightTruckSpeedGain_seg1,
                  lcAssertive=lightTruckAssertive_seg1,
                  startupDelay="1")

    
# Heavy trucks.
for i, vehLen in enumerate(["15.0", "15.5", "16.0"]):
    ET.SubElement(data, "vType", 
                  id="heavyTruck{}_seg1".format(i+1), 
                  vClass="truck",
                  length=vehLen,
                  tau=heavyTruckTau_seg1,
                  minGap=heavyTruckMinGap_seg1,
                  sigma=heavyTruckSigma_seg1,
                  speedFactor=heavyTruckSpeedFactor_seg1,
                  lcCooperative=heavyTruckCooperative_seg1,
                  lcStrategic=heavyTruckStrategic_seg1,
                  lcSpeedGain=heavyTruckSpeedGain_seg1,
                  lcAssertive=heavyTruckAssertive_seg1,
                  startupDelay="1")
    
    
    ET.SubElement(data, "vType", 
                  id="heavyTruck{}_cv_seg1".format(i+1), 
                  vClass="truck",
                  length=vehLen,
                  tau=heavyTruckTau_seg1,
                  minGap=heavyTruckMinGap_seg1,
                  sigma=heavyTruckSigma_seg1,
                  speedFactor=heavyTruckSpeedFactor_seg1,
                  lcCooperative=heavyTruckCooperative_seg1,
                  lcStrategic=heavyTruckStrategic_seg1,
                  lcSpeedGain=heavyTruckSpeedGain_seg1,
                  lcAssertive=heavyTruckAssertive_seg1,
                  startupDelay="1")
    

edge = ["S{}_M".format(i) for i in range(25, 38)]
lane = ["S38_M_0", "S38_M_1", "S38_M_2", "S38_M_3"]


for vType in ["car1", "car2", "car3", "car1_cv", "car2_cv", "car3_cv",
              "hov1", "hov2", "hov3", "hov1_cv", "hov2_cv", "hov3_cv",
              "lightTruck1", "lightTruck2", "lightTruck3", "lightTruck1_cv", "lightTruck2_cv", "lightTruck3_cv",
              "heavyTruck1", "heavyTruck2", "heavyTruck3", "heavyTruck1_cv", "heavyTruck2_cv", "heavyTruck3_cv"]:
    
    for e in edge:
        calibrator = ET.SubElement(data, "calibrator",
                                   id=e+"_"+vType,
                                   edge=e,
                                   pos="0",
                                   vTypes=vType)
            
        ET.SubElement(calibrator, "flow",
                      begin="0",
                      end=str(7*3600),
                      type=vType+"_seg1")
        
        
    for l in lane:
        calibrator = ET.SubElement(data, "calibrator",
                                   id=l+"_"+vType,
                                   lane=l,
                                   pos="0",
                                   vTypes=vType)
            
        ET.SubElement(calibrator, "flow",
                      begin="0",
                      end=str(7*3600),
                      type=vType+"_seg1")
        
        
            
dom = xml.dom.minidom.parseString(ET.tostring(data))
xml_string = dom.toprettyxml()
part1, part2 = xml_string.split('?>')

with open("I210.calibrator(mainSeg1).xml", 'w') as xfile:
    xfile.write(part1 + 'encoding=\"{}\"?>\n'.format(m_encoding) + part2)
    xfile.close()

# %% [markdown]
# # Segment 2

# %%
carTau_seg2 = "1.3"
carMinGap_seg2 = "3.0"
carSigma_seg2 = "0.2"
carSpeedFactor_seg2 = "normc(1.0,0.1,1.0,1.2)"
carCooperative_seg2 = "0.8"
carStrategic_seg2 = "10"
carSpeedGain_seg2 = "5"
carAssertive_seg2 = "2"

hovTau_seg2 = "1.3"
hovMinGap_seg2 = "3.0"
hovSigma_seg2 = "0.2"
hovSpeedFactor_seg2 = "normc(1.0,0.1,1.0,1.2)"
hovCooperative_seg2 = "0.8"
hovStrategic_seg2 = "10"
hovSpeedGain_seg2 = "5"
hovAssertive_seg2 = "2"

lightTruckTau_seg2 = "1.5"
lightTruckMinGap_seg2 = "3.5"
lightTruckSigma_seg2 = "0.2"
lightTruckSpeedFactor_seg2 = "normc(1.0,0.05,1.0,1.2)"
lightTruckCooperative_seg2 = "0.8"
lightTruckStrategic_seg2 = "10"
lightTruckSpeedGain_seg2 = "5"
lightTruckAssertive_seg2 = "1"

heavyTruckTau_seg2 = "1.5"
heavyTruckMinGap_seg2 = "3.5"
heavyTruckSigma_seg2 = "0.2"
heavyTruckSpeedFactor_seg2 = "normc(1.0,0.05,1.0,1.2)"
heavyTruckCooperative_seg2 = "0.8"
heavyTruckStrategic_seg2 = "10"
heavyTruckSpeedGain_seg2 = "5"
heavyTruckAssertive_seg2 = "1"

data = ET.Element('additional')

# car.
for i, vehLen in enumerate(["5.0", "5.5", "6.0"]):
    ET.SubElement(data, "vType", 
                  id="car{}_seg2".format(i+1), 
                  vClass="passenger",
                  length=vehLen,
                  tau=carTau_seg2,
                  minGap=carMinGap_seg2,
                  sigma=carSigma_seg2,
                  speedFactor=carSpeedFactor_seg2,
                  lcCooperative=carCooperative_seg2,
                  lcStrategic=carStrategic_seg2,
                  lcSpeedGain=carSpeedGain_seg2,
                  lcAssertive=carAssertive_seg2,
                  startupDelay="1")
    
    ET.SubElement(data, "vType", 
                  id="car{}_cv_seg2".format(i+1), 
                  vClass="passenger",
                  length=vehLen,
                  tau=carTau_seg2,
                  minGap=carMinGap_seg2,
                  sigma=carSigma_seg2,
                  speedFactor=carSpeedFactor_seg2,
                  lcCooperative=carCooperative_seg2,
                  lcStrategic=carStrategic_seg2,
                  lcSpeedGain=carSpeedGain_seg2,
                  lcAssertive=carAssertive_seg2,
                  startupDelay="1")

# HOV.
for i, vehLen in enumerate(["5.0", "5.5", "6.0"]):
    ET.SubElement(data, "vType", 
                  id="hov{}_seg2".format(i+1), 
                  vClass="hov",
                  length=vehLen,
                  tau=hovTau_seg2,
                  minGap=hovMinGap_seg2,
                  sigma=hovSigma_seg2,
                  speedFactor=hovSpeedFactor_seg2,
                  lcCooperative=hovCooperative_seg2,
                  lcStrategic=hovStrategic_seg2,
                  lcSpeedGain=hovSpeedGain_seg2,
                  lcAssertive=hovAssertive_seg2,
                  startupDelay="1")
    
    ET.SubElement(data, "vType", 
                  id="hov{}_cv_seg2".format(i+1), 
                  vClass="hov",
                  length=vehLen,
                  tau=hovTau_seg2,
                  minGap=hovMinGap_seg2,
                  sigma=hovSigma_seg2,
                  speedFactor=hovSpeedFactor_seg2,
                  lcCooperative=hovCooperative_seg2,
                  lcStrategic=hovStrategic_seg2,
                  lcSpeedGain=hovSpeedGain_seg2,
                  lcAssertive=hovAssertive_seg2,
                  startupDelay="1")


# Light trucks.
for i, vehLen in enumerate(["7.0", "7.5", "8.0"]):
    ET.SubElement(data, "vType", 
                  id="lightTruck{}_seg2".format(i+1), 
                  vClass="truck",
                  length=vehLen,
                  tau=lightTruckTau_seg2,
                  minGap=lightTruckMinGap_seg2,
                  sigma=lightTruckSigma_seg2,
                  speedFactor=lightTruckSpeedFactor_seg2,
                  lcCooperative=lightTruckCooperative_seg2,
                  lcStrategic=lightTruckStrategic_seg2,
                  lcSpeedGain=lightTruckSpeedGain_seg2,
                  lcAssertive=lightTruckAssertive_seg2,
                  startupDelay="1")
    
    
    ET.SubElement(data, "vType", 
                  id="lightTruck{}_cv_seg2".format(i+1), 
                  vClass="truck",
                  length=vehLen,
                  tau=lightTruckTau_seg2,
                  minGap=lightTruckMinGap_seg2,
                  sigma=lightTruckSigma_seg2,
                  speedFactor=lightTruckSpeedFactor_seg2,
                  lcCooperative=lightTruckCooperative_seg2,
                  lcStrategic=lightTruckStrategic_seg2,
                  lcSpeedGain=lightTruckSpeedGain_seg2,
                  lcAssertive=lightTruckAssertive_seg2,
                  startupDelay="1")

    
# Heavy trucks.
for i, vehLen in enumerate(["15.0", "15.5", "16.0"]):
    ET.SubElement(data, "vType", 
                  id="heavyTruck{}_seg2".format(i+1), 
                  vClass="truck",
                  length=vehLen,
                  tau=heavyTruckTau_seg2,
                  minGap=heavyTruckMinGap_seg2,
                  sigma=heavyTruckSigma_seg2,
                  speedFactor=heavyTruckSpeedFactor_seg2,
                  lcCooperative=heavyTruckCooperative_seg2,
                  lcStrategic=heavyTruckStrategic_seg2,
                  lcSpeedGain=heavyTruckSpeedGain_seg2,
                  lcAssertive=heavyTruckAssertive_seg2,
                  startupDelay="1")
    
    
    ET.SubElement(data, "vType", 
                  id="heavyTruck{}_cv_seg2".format(i+1), 
                  vClass="truck",
                  length=vehLen,
                  tau=heavyTruckTau_seg2,
                  minGap=heavyTruckMinGap_seg2,
                  sigma=heavyTruckSigma_seg2,
                  speedFactor=heavyTruckSpeedFactor_seg2,
                  lcCooperative=heavyTruckCooperative_seg2,
                  lcStrategic=heavyTruckStrategic_seg2,
                  lcSpeedGain=heavyTruckSpeedGain_seg2,
                  lcAssertive=heavyTruckAssertive_seg2,
                  startupDelay="1")
    

edge = ["S{}_M".format(i) for i in range(39, 43)]
lane = ["S43_M_0", "S43_M_1", "S43_M_2", "S43_M_3"]

for vType in ["car1", "car2", "car3", "car1_cv", "car2_cv", "car3_cv",
              "hov1", "hov2", "hov3", "hov1_cv", "hov2_cv", "hov3_cv",
              "lightTruck1", "lightTruck2", "lightTruck3", "lightTruck1_cv", "lightTruck2_cv", "lightTruck3_cv",
              "heavyTruck1", "heavyTruck2", "heavyTruck3", "heavyTruck1_cv", "heavyTruck2_cv", "heavyTruck3_cv"]:
    
    for e in edge:
        calibrator = ET.SubElement(data, "calibrator",
                                   id=e+"_"+vType,
                                   edge=e,
                                   pos="0",
                                   vTypes=vType)
            
        ET.SubElement(calibrator, "flow",
                      begin="0",
                      end=str(7*3600),
                      type=vType+"_seg2")
        
        
    for l in lane:
        calibrator = ET.SubElement(data, "calibrator",
                                   id=l+"_"+vType,
                                   lane=l,
                                   pos="0",
                                   vTypes=vType)
            
        ET.SubElement(calibrator, "flow",
                      begin="0",
                      end=str(7*3600),
                      type=vType+"_seg2")
        
            
dom = xml.dom.minidom.parseString(ET.tostring(data))
xml_string = dom.toprettyxml()
part1, part2 = xml_string.split('?>')

with open("I210.calibrator(mainSeg2).xml", 'w') as xfile:
    xfile.write(part1 + 'encoding=\"{}\"?>\n'.format(m_encoding) + part2)
    xfile.close()

# %% [markdown]
# # Segment 3

# %%
carTau_seg3 = "1.4"
carMinGap_seg3 = "3.0"
carSigma_seg3 = "0.2"
carSpeedFactor_seg3 = "normc(1.0,0.1,1.0,1.2)"
carCooperative_seg3 = "0.8"
carStrategic_seg3 = "10"
carSpeedGain_seg3 = "5"
carAssertive_seg3 = "2"

hovTau_seg3 = "1.4"
hovMinGap_seg3 = "3.0"
hovSigma_seg3 = "0.2"
hovSpeedFactor_seg3 = "normc(1.0,0.1,1.0,1.2)"
hovCooperative_seg3 = "0.8"
hovStrategic_seg3 = "10"
hovSpeedGain_seg3 = "5"
hovAssertive_seg3 = "2"

lightTruckTau_seg3 = "1.6"
lightTruckMinGap_seg3 = "3.5"
lightTruckSigma_seg3 = "0.2"
lightTruckSpeedFactor_seg3 = "normc(1.0,0.05,1.0,1.2)"
lightTruckCooperative_seg3 = "0.8"
lightTruckStrategic_seg3 = "10"
lightTruckSpeedGain_seg3 = "5"
lightTruckAssertive_seg3 = "1"

heavyTruckTau_seg3 = "1.6"
heavyTruckMinGap_seg3 = "3.5"
heavyTruckSigma_seg3 = "0.2"
heavyTruckSpeedFactor_seg3 = "normc(1.0,0.05,1.0,1.2)"
heavyTruckCooperative_seg3 = "0.8"
heavyTruckStrategic_seg3 = "10"
heavyTruckSpeedGain_seg3 = "5"
heavyTruckAssertive_seg3 = "1"

data = ET.Element('additional')

# car.
for i, vehLen in enumerate(["5.0", "5.5", "6.0"]):
    ET.SubElement(data, "vType", 
                  id="car{}_seg3".format(i+1), 
                  vClass="passenger",
                  length=vehLen,
                  tau=carTau_seg3,
                  minGap=carMinGap_seg3,
                  sigma=carSigma_seg3,
                  speedFactor=carSpeedFactor_seg3,
                  lcCooperative=carCooperative_seg3,
                  lcStrategic=carStrategic_seg3,
                  lcSpeedGain=carSpeedGain_seg3,
                  lcAssertive=carAssertive_seg3,
                  startupDelay="1")
    
    ET.SubElement(data, "vType", 
                  id="car{}_cv_seg3".format(i+1), 
                  vClass="passenger",
                  length=vehLen,
                  tau=carTau_seg3,
                  minGap=carMinGap_seg3,
                  sigma=carSigma_seg3,
                  speedFactor=carSpeedFactor_seg3,
                  lcCooperative=carCooperative_seg3,
                  lcStrategic=carStrategic_seg3,
                  lcSpeedGain=carSpeedGain_seg3,
                  lcAssertive=carAssertive_seg3,
                  startupDelay="1")

# HOV.
for i, vehLen in enumerate(["5.0", "5.5", "6.0"]):
    ET.SubElement(data, "vType", 
                  id="hov{}_seg3".format(i+1), 
                  vClass="hov",
                  length=vehLen,
                  tau=hovTau_seg3,
                  minGap=hovMinGap_seg3,
                  sigma=hovSigma_seg3,
                  speedFactor=hovSpeedFactor_seg3,
                  lcCooperative=hovCooperative_seg3,
                  lcStrategic=hovStrategic_seg3,
                  lcSpeedGain=hovSpeedGain_seg3,
                  lcAssertive=hovAssertive_seg3,
                  startupDelay="1")
    
    ET.SubElement(data, "vType", 
                  id="hov{}_cv_seg3".format(i+1), 
                  vClass="hov",
                  length=vehLen,
                  tau=hovTau_seg3,
                  minGap=hovMinGap_seg3,
                  sigma=hovSigma_seg3,
                  speedFactor=hovSpeedFactor_seg3,
                  lcCooperative=hovCooperative_seg3,
                  lcStrategic=hovStrategic_seg3,
                  lcSpeedGain=hovSpeedGain_seg3,
                  lcAssertive=hovAssertive_seg3,
                  startupDelay="1")


# Light trucks.
for i, vehLen in enumerate(["7.0", "7.5", "8.0"]):
    ET.SubElement(data, "vType", 
                  id="lightTruck{}_seg3".format(i+1), 
                  vClass="truck",
                  length=vehLen,
                  tau=lightTruckTau_seg3,
                  minGap=lightTruckMinGap_seg3,
                  sigma=lightTruckSigma_seg3,
                  speedFactor=lightTruckSpeedFactor_seg3,
                  lcCooperative=lightTruckCooperative_seg3,
                  lcStrategic=lightTruckStrategic_seg3,
                  lcSpeedGain=lightTruckSpeedGain_seg3,
                  lcAssertive=lightTruckAssertive_seg3,
                  startupDelay="1")
    
    ET.SubElement(data, "vType", 
                  id="lightTruck{}_cv_seg3".format(i+1), 
                  vClass="truck",
                  length=vehLen,
                  tau=lightTruckTau_seg3,
                  minGap=lightTruckMinGap_seg3,
                  sigma=lightTruckSigma_seg3,
                  speedFactor=lightTruckSpeedFactor_seg3,
                  lcCooperative=lightTruckCooperative_seg3,
                  lcStrategic=lightTruckStrategic_seg3,
                  lcSpeedGain=lightTruckSpeedGain_seg3,
                  lcAssertive=lightTruckAssertive_seg3,
                  startupDelay="1")

# Heavy trucks.
for i, vehLen in enumerate(["15.0", "15.5", "16.0"]):
    ET.SubElement(data, "vType", 
                  id="heavyTruck{}_seg3".format(i+1), 
                  vClass="truck",
                  length=vehLen,
                  tau=heavyTruckTau_seg3,
                  minGap=heavyTruckMinGap_seg3,
                  sigma=heavyTruckSigma_seg3,
                  speedFactor=heavyTruckSpeedFactor_seg3,
                  lcCooperative=heavyTruckCooperative_seg3,
                  lcStrategic=heavyTruckStrategic_seg3,
                  lcSpeedGain=heavyTruckSpeedGain_seg3,
                  lcAssertive=heavyTruckAssertive_seg3,
                  startupDelay="1")
    
    ET.SubElement(data, "vType", 
                  id="heavyTruck{}_cv_seg3".format(i+1), 
                  vClass="truck",
                  length=vehLen,
                  tau=heavyTruckTau_seg3,
                  minGap=heavyTruckMinGap_seg3,
                  sigma=heavyTruckSigma_seg3,
                  speedFactor=heavyTruckSpeedFactor_seg3,
                  lcCooperative=heavyTruckCooperative_seg3,
                  lcStrategic=heavyTruckStrategic_seg3,
                  lcSpeedGain=heavyTruckSpeedGain_seg3,
                  lcAssertive=heavyTruckAssertive_seg3,
                  startupDelay="1")


edge = ["S{}_M".format(i) for i in range(44, 56)]
lane = ["S56_M_0", "S56_M_1", "S56_M_2", "S56_M_3"]

for vType in ["car1", "car2", "car3", "car1_cv", "car2_cv", "car3_cv",
              "hov1", "hov2", "hov3", "hov1_cv", "hov2_cv", "hov3_cv",
              "lightTruck1", "lightTruck2", "lightTruck3", "lightTruck1_cv", "lightTruck2_cv", "lightTruck3_cv",
              "heavyTruck1", "heavyTruck2", "heavyTruck3", "heavyTruck1_cv", "heavyTruck2_cv", "heavyTruck3_cv"]:
    
    for e in edge:
        calibrator = ET.SubElement(data, "calibrator",
                                   id=e+"_"+vType,
                                   edge=e,
                                   pos="0",
                                   vTypes=vType)
            
        ET.SubElement(calibrator, "flow",
                      begin="0",
                      end=str(7*3600),
                      type=vType+"_seg3")
            
    for l in lane:
        calibrator = ET.SubElement(data, "calibrator",
                                   id=l+"_"+vType,
                                   lane=l,
                                   pos="0",
                                   vTypes=vType)
            
        ET.SubElement(calibrator, "flow",
                      begin="0",
                      end=str(7*3600),
                      type=vType+"_seg3")
            
dom = xml.dom.minidom.parseString(ET.tostring(data))
xml_string = dom.toprettyxml()
part1, part2 = xml_string.split('?>')

with open("I210.calibrator(mainSeg3).xml", 'w') as xfile:
    xfile.write(part1 + 'encoding=\"{}\"?>\n'.format(m_encoding) + part2)
    xfile.close()
